# %% [markdown]
# # Simple Proportional-Integral (PI) Speed Control Simulation
#
# Copyright &copy; 2022-2024 [Joshua A. Marshall](https://www.ece.queensu.ca/people/j-marshall)
#
# This simple simulation illustrates **proportional-integral (PI) control** in the context of a cruise control application for a simple 1D mobile robot.
#
# ## Import Packages
#
# We use [Numpy](https://numpy.org) for handling arrays and [Matplotlib](https://matplotlib.org) for plotting.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Simulation Setup
#
# Set the simulation time as `SIM_TIME` [s], the sample period as `T` [s] and the mobile robot's mass as `M` [kg].

# %%
SIM_TIME = 30.0
T = 0.4
M = 10

# %% [markdown]
# Set up an array of simulation times `t` and find the total number of simulation data points `N`.

# %%
t = np.arange(0, SIM_TIME, T)
N = np.size(t)

# %% [markdown]
# Write a function to model the mobile robot's speed `v` [m/s] as a function of the force input `u` [N].  Suppose, in this case that the vehicle is on a slope with angle `theta` [rad].

# %%
def vehicle_speed(v, u, T, theta):
    """Discrete-time 1D vehicle speed model."""
    v_new = v + T * 1 / M * (u - M * 9.81 * np.sin(theta))
    return v_new

# %% [markdown]
# ## Run the Simulation
#
# Set the desired speed (i.e., cruise control set-point).

# %%
v_d = 4.0

# %% [markdown]
# Initialize the variables and run the simulation in a `for` loop.  Pick controller gains `k_P` and `k_I` and the slope of the terrain `theta` [rad].

# %%
# Initialize some variables
v = np.zeros(N)
u = np.zeros(N)
error_int = 0.0

# Initialize the state and inputs
v[0] = 0.0
u[0] = 0.0

# Set the parameters
k_P = 5.0
k_I = 2.0
theta = 180 / np.pi * 10.0

# For each time step compute the vehicle motion and new input
for k in range(1, N):
    v[k] = vehicle_speed(v[k - 1], u[k - 1], T, theta)
    error = v_d - v[k]
    error_int += T * error
    u[k] = k_P * error + k_I * error_int

# %% [markdown]
# ## Plot the Simulation Output

# %%
# Optional setup
plt.rc("text", usetex=True)
plt.rc("text.latex", preamble=r"\usepackage{arev,amsmath}")

# Plot the speed and input versus time
fig1 = plt.figure(1)
ax1a = plt.subplot(211)
plt.plot(t, v, "C0")
plt.grid(color="0.95")
plt.ylabel(r"$v$ [m/s]")
plt.setp(ax1a, xticklabels=[])
ax1b = plt.subplot(212)
plt.step(t, u, "C1", where="post")
plt.grid(color="0.95")
plt.ylabel(r"$u$ [N]")
plt.xlabel(r"$t$ [s]")
plt.show()
